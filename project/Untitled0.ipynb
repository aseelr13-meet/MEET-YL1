# %%
import csv

# %%
f = open('cheese.csv', 'rb')
reader = csv.reader(f)
rownum = 0
luctic = []
acetic = []
for row in reader:
    if rownum != 0 :
        a = row[0]
        r = a.split()
        b = r[1::]
        d = map(float ,r )
        luctic.append(d[1])
        acetic.append(d[2])
    rownum += 1

print luctic
print acitic
        
f.close()
# Out:
# [12.3, 20.9, 39.0, 47.9, 5.6, 25.9, 37.3, 21.9, 18.1, 21.0, 34.9, 57.2, 0.7, 25.9, 54.9, 40.9, 15.9, 6.4, 18.0, 38.9, 14.0, 15.2, 32.0, 56.7, 16.8, 11.6, 26.5, 0.7, 13.4, 5.5]
# []

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title('luctic and acetic amount in cheese')
ax.set_xlabel('luctic amount')
ax.set_ylabel('acetic amount')
ax.scatter(luctic,acetic)
fig.savefig("cheese chart.png")

# %% [markdown]
# this graph shows the relationship between the amount of acetic and the lactic amount found in cheese
